# %%
import numpy as np
from keras.models import Model
from keras.layers import Input,LSTM,Dense

# %%
#Define the input sequence length and dimensionlity
input_seq_length=10
input_dim=20

# %%
#Define the output sequence length and dimensionality
output_seq_length=5
out_dim=10

# %%
#Define the number of units in the LSTM layers
latent_dim=256

# %%
#Define the input layer
encoder_input=Input(shape=(input_seq_length,input_dim))

# %%
#Define the encoder LSTM layer
encoder_lstm=LSTM(latent_dim,return_state=True)#only return last state

# %%
#Get the encoder outputs and states
encoder_outputs,state_h,state_c=encoder_lstm(encoder_input)

# %%
#Keep only the states
encoder_states=[state_h,state_c]

# %%
#Define the decoder input layer
decoder_input=Input(shape=(output_seq_length,out_dim))

# %%
#Define the decoder LSTM layer, wit the encoder states as initial state
decoder_lstm=LSTM(latent_dim,return_sequences=True,return_state=True)

# %%
#Get the decoder outputs
decoder_output,x,y=decoder_lstm(decoder_input,initial_state=encoder_states)

# %%
#Define the output layer
decoder_dense=Dense(out_dim, activation='softmax')
decoder_outputs=decoder_dense(decoder_output)

# %%
#Define the model
model=Model([encoder_input,decoder_input],decoder_outputs)

# %%
#Compile the model
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
#Print model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 10, 20)]             0         []
#
#  input_2 (InputLayer)        [(None, 5, 10)]              0         []
#
#  lstm_1 (LSTM)               [(None, 256),                283648    ['input_1[0][0]']
#                               (None, 256),
#                               (None, 256)]
#
#  lstm_2 (LSTM)               [(None, 5, 256),             273408    ['input_2[0][0]',
#                               (None, 256),                           'lstm_1[0][1]',
#                               (None, 256)]                           'lstm_1[0][2]']
#
#  dense_1 (Dense)             (None, 5, 10)                2570      ['lstm_2[3][0]']
#
# ==================================================================================================
# Total params: 559626 (2.13 MB)
# Trainable params: 559626 (2.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
#Generating dummy training data
X_train_encoder = np.random.randn(1000, input_seq_length, input_dim)
X_train_decoder = np.random.randn(1000, output_seq_length, out_dim)
y_train = np.random.randn(1000, output_seq_length, out_dim)

# %%
#Train the model
model.fit([X_train_encoder,X_train_decoder],y_train,epochs=50,batch_size=32)
# Out:
# Epoch 1/50
# 32/32 [==============================] - 1s 40ms/step - loss: -0.1116 - accuracy: 0.1058
# Epoch 2/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1079 - accuracy: 0.1052
# Epoch 3/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1041 - accuracy: 0.1038
# Epoch 4/50
# 32/32 [==============================] - 1s 40ms/step - loss: -0.1291 - accuracy: 0.0942
# Epoch 5/50
# 32/32 [==============================] - 1s 40ms/step - loss: -0.1031 - accuracy: 0.1032
# Epoch 6/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1031 - accuracy: 0.0924
# Epoch 7/50
# 32/32 [==============================] - 2s 64ms/step - loss: -0.1163 - accuracy: 0.0970
# Epoch 8/50
# 32/32 [==============================] - 2s 57ms/step - loss: -0.1123 - accuracy: 0.0990
# Epoch 9/50
# 32/32 [==============================] - 1s 40ms/step - loss: -0.1146 - accuracy: 0.1044
# Epoch 10/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1085 - accuracy: 0.1006
# Epoch 11/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1088 - accuracy: 0.1004
# Epoch 12/50
# 32/32 [==============================] - 1s 40ms/step - loss: -0.1115 - accuracy: 0.0962
# Epoch 13/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1010 - accuracy: 0.0976
# Epoch 14/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1097 - accuracy: 0.1044
# Epoch 15/50
# 32/32 [==============================] - 1s 40ms/step - loss: -0.1089 - accuracy: 0.0972
# Epoch 16/50
# 32/32 [==============================] - 2s 57ms/step - loss: -0.1052 - accuracy: 0.0954
# Epoch 17/50
# 32/32 [==============================] - 2s 52ms/step - loss: -0.1075 - accuracy: 0.1016
# Epoch 18/50
# 32/32 [==============================] - 1s 41ms/step - loss: -0.1104 - accuracy: 0.1020
# Epoch 19/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1141 - accuracy: 0.0970
# Epoch 20/50
# 32/32 [==============================] - 1s 40ms/step - loss: -0.1056 - accuracy: 0.0978
# Epoch 21/50
# 32/32 [==============================] - 1s 40ms/step - loss: -0.1225 - accuracy: 0.0996
# Epoch 22/50
# 32/32 [==============================] - 1s 40ms/step - loss: -0.1127 - accuracy: 0.1062
# Epoch 23/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1047 - accuracy: 0.1028
# Epoch 24/50
# 32/32 [==============================] - 1s 40ms/step - loss: -0.1017 - accuracy: 0.0990
# Epoch 25/50
# 32/32 [==============================] - 2s 56ms/step - loss: -0.1162 - accuracy: 0.1006
# Epoch 26/50
# 32/32 [==============================] - 2s 54ms/step - loss: -0.1053 - accuracy: 0.0958
# Epoch 27/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1135 - accuracy: 0.1000
# Epoch 28/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1105 - accuracy: 0.0998
# Epoch 29/50
# 32/32 [==============================] - 1s 40ms/step - loss: -0.1123 - accuracy: 0.1048
# Epoch 30/50
# 32/32 [==============================] - 1s 40ms/step - loss: -0.1245 - accuracy: 0.0952
# Epoch 31/50
# 32/32 [==============================] - 1s 40ms/step - loss: -0.1061 - accuracy: 0.0910
# Epoch 32/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1100 - accuracy: 0.0970
# Epoch 33/50
# 32/32 [==============================] - 1s 40ms/step - loss: -0.1124 - accuracy: 0.1036
# Epoch 34/50
# 32/32 [==============================] - 2s 55ms/step - loss: -0.1008 - accuracy: 0.0976
# Epoch 35/50
# 32/32 [==============================] - 2s 55ms/step - loss: -0.1187 - accuracy: 0.0970
# Epoch 36/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.0975 - accuracy: 0.0978
# Epoch 37/50
# 32/32 [==============================] - 1s 40ms/step - loss: -0.1017 - accuracy: 0.0986
# Epoch 38/50
# 32/32 [==============================] - 1s 40ms/step - loss: -0.1052 - accuracy: 0.0976
# Epoch 39/50
# 32/32 [==============================] - 1s 41ms/step - loss: -0.1163 - accuracy: 0.1060
# Epoch 40/50
# 32/32 [==============================] - 1s 41ms/step - loss: -0.0985 - accuracy: 0.0986
# Epoch 41/50
# 32/32 [==============================] - 1s 40ms/step - loss: -0.1076 - accuracy: 0.0910
# Epoch 42/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1039 - accuracy: 0.0986
# Epoch 43/50
# 32/32 [==============================] - 2s 55ms/step - loss: -0.1138 - accuracy: 0.0942
# Epoch 44/50
# 32/32 [==============================] - 2s 54ms/step - loss: -0.1235 - accuracy: 0.1016
# Epoch 45/50
# 32/32 [==============================] - 1s 40ms/step - loss: -0.1112 - accuracy: 0.1042
# Epoch 46/50
# 32/32 [==============================] - 1s 40ms/step - loss: -0.1070 - accuracy: 0.0992
# Epoch 47/50
# 32/32 [==============================] - 1s 40ms/step - loss: -0.1002 - accuracy: 0.1004
# Epoch 48/50
# 32/32 [==============================] - 1s 40ms/step - loss: -0.1101 - accuracy: 0.1048
# Epoch 49/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1154 - accuracy: 0.0964
# Epoch 50/50
# 32/32 [==============================] - 1s 40ms/step - loss: -0.1202 - accuracy: 0.0974

# %%
# Generate dummy test data
X_test_encoder = np.random.randn(200, input_seq_length, input_dim)
X_test_decoder = np.random.randn(200, output_seq_length, out_dim)

# %%
# Predict using the trained model
predictions = model.predict([X_test_encoder, X_test_decoder])
print("Predictions shape:", predictions.shape)
# Out:
# 7/7 [==============================] - 2s 22ms/step
# Predictions shape: (200, 5, 10)
